# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

def scrape_league_data(league_name, url, table_id=None, season="2024/25"):
    print(f"Scraping {league_name}...")

    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers, verify=False)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", id=table_id) if table_id else soup.find("table")
    if not table:
        print(f"❌ Table not found for {league_name}")
        return None

    df = pd.read_html(str(table))[0]
    df['League'] = league_name
    df['Season'] = season

    return df

# %%
# List of leagues to scrape
years = ["2024-2025","2023-2024","2022-2023"]
leagueinfo = [
    {
        "name": "Bundesliga",
        "url": "https://fbref.com/en/comps/20/{year}/schedule/{year}-Bundesliga-Scores-and-Fixtures"
    },
    {
        "name": "Premier League",
        "url": "https://fbref.com/en/comps/9/{year}/schedule/{year}-Premier-League-Scores-and-Fixtures"
    },
    {
        "name": "Serie A",
        "url": "https://fbref.com/en/comps/11/{year}/schedule/{year}-Serie-A-Scores-and-Fixtures"
    }
]

leagues = []
for year in years:
    for league in leagueinfo:
        leagues.append({
            "name": f"{league['name']} {year}",
            "url": league["url"].format(year=year),
            "season": year.replace("-", "/")
        })

league_dfs = {}
combined_list = []

for league in leagues:
    df = scrape_league_data(league["name"], league["url"])
    if df is not None:
        league_dfs[league["name"]] = df  # Store separately
        combined_list.append(df)         # Also save for merging

# %%
league_dfs
# Out:
# {'Bundesliga 2024-2025':                                          Round    Wk  Day        Date   Time  \
#  0                                   Bundesliga   1.0  Fri  2024-08-23  20:30
#  1                                   Bundesliga   1.0  Sat  2024-08-24  15:30
#  2                                   Bundesliga   1.0  Sat  2024-08-24  15:30
#  3                                   Bundesliga   1.0  Sat  2024-08-24  15:30
#  4                                   Bundesliga   1.0  Sat  2024-08-24  15:30
#  ..                                         ...   ...  ...         ...    ...
#  337                                 Bundesliga  34.0  Sat  2025-05-17  15:30
#  338                                 Bundesliga  34.0  Sat  2025-05-17  15:30
#  339                                        NaN   NaN  NaN         NaN    NaN
#  340  German 1/2 Relegation/Promotion play-offs   NaN  Thu  2025-05-22  20:30
#  341  German 1/2 Relegation/Promotion play-offs   NaN  Mon  2025-05-26  20:30
#
#             Home   xG Score  xG.1           Away  Attendance  \
#  0      Gladbach  1.6   2–3   2.7     Leverkusen     54042.0
#  1    Hoffenheim  3.5   3–2   1.7  Holstein Kiel     18503.0
#  2      Mainz 05  1.2   1–1   0.6   Union Berlin     31500.0
#  3      Augsburg  1.0   2–2   1.4  Werder Bremen     30660.0
#  4      Freiburg  2.1   3–1   0.4      Stuttgart     34700.0
#  ..          ...  ...   ...   ...            ...         ...
#  337    Dortmund  2.4   3–0   0.8  Holstein Kiel     81365.0
#  338  Hoffenheim  0.4   0–4   1.4  Bayern Munich     30150.0
#  339         NaN  NaN   NaN   NaN            NaN         NaN
#  340  Heidenheim  NaN   2–2   NaN     Elversberg     15000.0
#  341  Elversberg  NaN   1–2   NaN     Heidenheim      9105.0
#
#                                    Venue           Referee  Match Report  \
#  0              Stadion im Borussia-Park   Robert Schröder  Match Report
#  1                         PreZero Arena    Tobias Stieler  Match Report
#  2                            Mewa Arena       Harm Osmers  Match Report
#  3                             WWK Arena  Sascha Stegemann  Match Report
#  4                   Europa-Park Stadion       Tobias Welz  Match Report
#  ..                                  ...               ...           ...
#  337                   Signal Iduna Park       Harm Osmers  Match Report
#  338                       PreZero Arena   Daniel Schlager  Match Report
#  339                                 NaN               NaN           NaN
#  340                         Voith-Arena    Sven Jablonski  Match Report
#  341  Ursapharm-Arena an der Kaiserlinde  Sascha Stegemann  Match Report
#
#                            Notes                League   Season
#  0                           NaN  Bundesliga 2024-2025  2024/25
#  1                           NaN  Bundesliga 2024-2025  2024/25
#  2                           NaN  Bundesliga 2024-2025  2024/25
#  3                           NaN  Bundesliga 2024-2025  2024/25
#  4                           NaN  Bundesliga 2024-2025  2024/25
#  ..                          ...                   ...      ...
#  337                         NaN  Bundesliga 2024-2025  2024/25
#  338                         NaN  Bundesliga 2024-2025  2024/25
#  339                         NaN  Bundesliga 2024-2025  2024/25
#  340                  Leg 1 of 2  Bundesliga 2024-2025  2024/25
#  341  Leg 2 of 2; Heidenheim won  Bundesliga 2024-2025  2024/25
#
#  [342 rows x 17 columns],
#  'Premier League 2024-2025':        Wk  Day        Date   Time             Home   xG Score  xG.1  \
#  0     1.0  Fri  2024-08-16  20:00   Manchester Utd  2.4   1–0   0.4
#  1     1.0  Sat  2024-08-17  12:30     Ipswich Town  0.5   0–2   2.6
#  2     1.0  Sat  2024-08-17  15:00    Newcastle Utd  0.3   1–0   1.8
#  3     1.0  Sat  2024-08-17  15:00          Everton  0.5   0–3   1.4
#  4     1.0  Sat  2024-08-17  15:00  Nott'ham Forest  1.3   1–1   1.2
#  ..    ...  ...         ...    ...              ...  ...   ...   ...
#  415  38.0  Sun  2025-05-25  16:00  Nott'ham Forest  1.2   0–1   1.1
#  416  38.0  Sun  2025-05-25  16:00           Fulham  1.3   0–2   3.0
#  417  38.0  Sun  2025-05-25  16:00    Newcastle Utd  1.2   0–1   1.2
#  418  38.0  Sun  2025-05-25  16:00      Bournemouth  1.6   2–0   0.3
#  419  38.0  Sun  2025-05-25  16:00        Tottenham  2.0   1–4   2.2
#
#                  Away  Attendance                      Venue          Referee  \
#  0             Fulham     73297.0               Old Trafford     Robert Jones
#  1          Liverpool     30014.0       Portman Road Stadium     Tim Robinson
#  2        Southampton     52196.0             St James' Park     Craig Pawson
#  3           Brighton     39217.0              Goodison Park     Simon Hooper
#  4        Bournemouth     29763.0            The City Ground   Michael Oliver
#  ..               ...         ...                        ...              ...
#  415          Chelsea     30263.0            The City Ground   Anthony Taylor
#  416  Manchester City     27671.0             Craven Cottage      Andy Madley
#  417          Everton     52221.0             St James' Park  Tony Harrington
#  418   Leicester City     11238.0           Vitality Stadium      Lewis Smith
#  419         Brighton     61449.0  Tottenham Hotspur Stadium     Robert Jones
#
#       Match Report  Notes                    League   Season
#  0    Match Report    NaN  Premier League 2024-2025  2024/25
#  1    Match Report    NaN  Premier League 2024-2025  2024/25
#  2    Match Report    NaN  Premier League 2024-2025  2024/25
#  3    Match Report    NaN  Premier League 2024-2025  2024/25
#  4    Match Report    NaN  Premier League 2024-2025  2024/25
#  ..            ...    ...                       ...      ...
#  415  Match Report    NaN  Premier League 2024-2025  2024/25
#  416  Match Report    NaN  Premier League 2024-2025  2024/25
#  417  Match Report    NaN  Premier League 2024-2025  2024/25
#  418  Match Report    NaN  Premier League 2024-2025  2024/25
#  419  Match Report    NaN  Premier League 2024-2025  2024/25
#
#  [420 rows x 16 columns],
#  'Serie A 2024-2025':        Wk  Day        Date   Time      Home   xG Score  xG.1           Away  \
#  0     1.0  Sat  2024-08-17  18:30     Genoa  2.1   2–2   1.9          Inter
#  1     1.0  Sat  2024-08-17  18:30     Parma  1.7   1–1   0.7     Fiorentina
#  2     1.0  Sat  2024-08-17  20:45    Empoli  0.5   0–0   0.3          Monza
#  3     1.0  Sat  2024-08-17  20:45     Milan  2.1   2–2   1.0         Torino
#  4     1.0  Sun  2024-08-18  18:30   Bologna  3.2   1–1   0.9        Udinese
#  ..    ...  ...         ...    ...       ...  ...   ...   ...            ...
#  415  38.0  Sun  2025-05-25  20:45     Lazio  1.8   0–1   0.4          Lecce
#  416  38.0  Sun  2025-05-25  20:45    Torino  0.5   0–2   1.9           Roma
#  417  38.0  Sun  2025-05-25  20:45   Venezia  0.9   2–3   1.9       Juventus
#  418  38.0  Sun  2025-05-25  20:45  Atalanta  1.2   2–3   2.5          Parma
#  419  38.0  Sun  2025-05-25  20:45    Empoli  0.9   1–2   0.8  Hellas Verona
#
#       Attendance                                        Venue  \
#  0       33300.0               Stadio Comunale Luigi Ferraris
#  1       21384.0                         Stadio Ennio Tardini
#  2        7746.0  Stadio Carlo Castellani - Computer Gross...
#  3       70742.0                       Stadio Giuseppe Meazza
#  4       26418.0                       Stadio Renato Dall'Ara
#  ..          ...                                          ...
#  415     53000.0                              Stadio Olimpico
#  416     24252.0                Stadio Olimpico Grande Torino
#  417     12048.0                      Stadio Pier Luigi Penzo
#  418     23161.0                               Gewiss Stadium
#  419     14025.0  Stadio Carlo Castellani - Computer Gross...
#
#                          Referee  Match Report Notes             League  \
#  0             Ermanno Feliciani  Match Report   NaN  Serie A 2024-2025
#  1              Giovanni Ayroldi  Match Report   NaN  Serie A 2024-2025
#  2                Michael Fabbri  Match Report   NaN  Serie A 2024-2025
#  3                 Fabio Maresca  Match Report   NaN  Serie A 2024-2025
#  4    Maria Sole Ferrieri Caputi  Match Report   NaN  Serie A 2024-2025
#  ..                          ...           ...   ...                ...
#  415              Michael Fabbri  Match Report   NaN  Serie A 2024-2025
#  416              Marco Di Bello  Match Report   NaN  Serie A 2024-2025
#  417              Andrea Colombo  Match Report   NaN  Serie A 2024-2025
#  418             Livio Marinelli  Match Report   NaN  Serie A 2024-2025
#  419              Daniele Doveri  Match Report   NaN  Serie A 2024-2025
#
#        Season
#  0    2024/25
#  1    2024/25
#  2    2024/25
#  3    2024/25
#  4    2024/25
#  ..       ...
#  415  2024/25
#  416  2024/25
#  417  2024/25
#  418  2024/25
#  419  2024/25
#
#  [420 rows x 16 columns],
#  'Bundesliga 2023-2024':                                          Round    Wk  Day        Date   Time  \
#  0                                   Bundesliga   1.0  Fri  2023-08-18  20:30
#  1                                   Bundesliga   1.0  Sat  2023-08-19  15:30
#  2                                   Bundesliga   1.0  Sat  2023-08-19  15:30
#  3                                   Bundesliga   1.0  Sat  2023-08-19  15:30
#  4                                   Bundesliga   1.0  Sat  2023-08-19  15:30
#  ..                                         ...   ...  ...         ...    ...
#  339                                 Bundesliga  34.0  Sat  2024-05-18  15:30
#  340                                 Bundesliga  34.0  Sat  2024-05-18  15:30
#  341                                        NaN   NaN  NaN         NaN    NaN
#  342  German 1/2 Relegation/Promotion play-offs   NaN  Thu  2024-05-23  20:30
#  343  German 1/2 Relegation/Promotion play-offs   NaN  Mon  2024-05-27  20:30
#
#                Home   xG        Score  xG.1           Away  Attendance  \
#  0    Werder Bremen  0.6          0–4   2.8  Bayern Munich     42100.0
#  1        Stuttgart  3.0          5–0   0.8         Bochum     53000.0
#  2       Hoffenheim  1.4          1–2   2.6       Freiburg     25890.0
#  3         Augsburg  2.3          4–4   1.7       Gladbach     30660.0
#  4       Leverkusen  1.4          3–2   1.6     RB Leipzig     29464.0
#  ..             ...  ...          ...   ...            ...         ...
#  339      Wolfsburg  0.8          1–3   1.8       Mainz 05     26627.0
#  340     Heidenheim  1.0          4–1   2.3           Köln     15000.0
#  341            NaN  NaN          NaN   NaN            NaN         NaN
#  342         Bochum  NaN          0–3   NaN     Düsseldorf     26000.0
#  343     Düsseldorf  NaN  (5) 0–3 (6)   NaN         Bochum     51500.0
#
#                         Venue           Referee  Match Report  \
#  0    Wohninvest Weserstadion      Felix Zwayer  Match Report
#  1                   MHPArena    Daniel Siebert  Match Report
#  2              PreZero Arena    Sven Jablonski  Match Report
#  3                  WWK Arena   Daniel Schlager  Match Report
#  4                   BayArena       Felix Brych  Match Report
#  ..                       ...               ...           ...
#  339         Volkswagen Arena  Frank Willenborg  Match Report
#  340              Voith-Arena       Tobias Welz  Match Report
#  341                      NaN               NaN           NaN
#  342      Vonovia Ruhrstadion   Robert Schröder  Match Report
#  343        Merkur Spielarena     Deniz Aytekin  Match Report
#
#                                                   Notes                League  \
#  0                                                  NaN  Bundesliga 2023-2024
#  1                                                  NaN  Bundesliga 2023-2024
#  2                                                  NaN  Bundesliga 2023-2024
#  3                                                  NaN  Bundesliga 2023-2024
#  4                                                  NaN  Bundesliga 2023-2024
#  ..                                                 ...                   ...
#  339                                                NaN  Bundesliga 2023-2024
#  340                                                NaN  Bundesliga 2023-2024
#  341                                                NaN  Bundesliga 2023-2024
#  342                                         Leg 1 of 2  Bundesliga 2023-2024
#  343  Leg 2 of 2; Bochum won; Bochum won on penalty ...  Bundesliga 2023-2024
#
#        Season
#  0    2024/25
#  1    2024/25
#  2    2024/25
#  3    2024/25
#  4    2024/25
#  ..       ...
#  339  2024/25
#  340  2024/25
#  341  2024/25
#  342  2024/25
#  343  2024/25
#
#  [344 rows x 17 columns],
#  'Premier League 2023-2024':        Wk  Day        Date   Time             Home   xG Score  xG.1  \
#  0     1.0  Fri  2023-08-11  20:00          Burnley  0.3   0–3   1.9
#  1     1.0  Sat  2023-08-12  12:30          Arsenal  0.8   2–1   1.2
#  2     1.0  Sat  2023-08-12  15:00          Everton  2.7   0–1   1.5
#  3     1.0  Sat  2023-08-12  15:00         Brighton  4.0   4–1   1.5
#  4     1.0  Sat  2023-08-12  15:00    Sheffield Utd  0.5   0–1   1.9
#  ..    ...  ...         ...    ...              ...  ...   ...   ...
#  418  38.0  Sun  2024-05-19  16:00         Brighton  1.7   0–2   1.3
#  419  38.0  Sun  2024-05-19  16:00        Brentford  1.1   2–4   3.4
#  420  38.0  Sun  2024-05-19  16:00  Manchester City  1.9   3–1   0.4
#  421  38.0  Sun  2024-05-19  16:00          Arsenal  2.9   2–1   0.6
#  422  38.0  Sun  2024-05-19  16:00    Sheffield Utd  1.0   0–3   3.1
#
#                  Away  Attendance                                   Venue  \
#  0    Manchester City     21572.0                               Turf Moor
#  1    Nott'ham Forest     59984.0                        Emirates Stadium
#  2             Fulham     39940.0                           Goodison Park
#  3         Luton Town     31872.0  The American Express Community Stadium
#  4     Crystal Palace     31194.0                            Bramall Lane
#  ..               ...         ...                                     ...
#  418   Manchester Utd     31662.0  The American Express Community Stadium
#  419    Newcastle Utd     17124.0                 Gtech Community Stadium
#  420         West Ham     55097.0                          Etihad Stadium
#  421          Everton     60312.0                        Emirates Stadium
#  422        Tottenham     29116.0                            Bramall Lane
#
#              Referee  Match Report  Notes                    League   Season
#  0      Craig Pawson  Match Report    NaN  Premier League 2023-2024  2024/25
#  1    Michael Oliver  Match Report    NaN  Premier League 2023-2024  2024/25
#  2    Stuart Attwell  Match Report    NaN  Premier League 2023-2024  2024/25
#  3       David Coote  Match Report    NaN  Premier League 2023-2024  2024/25
#  4       John Brooks  Match Report    NaN  Premier League 2023-2024  2024/25
#  ..              ...           ...    ...                       ...      ...
#  418    Craig Pawson  Match Report    NaN  Premier League 2023-2024  2024/25
#  419    Simon Hooper  Match Report    NaN  Premier League 2023-2024  2024/25
#  420     John Brooks  Match Report    NaN  Premier League 2023-2024  2024/25
#  421  Michael Oliver  Match Report    NaN  Premier League 2023-2024  2024/25
#  422     Andy Madley  Match Report    NaN  Premier League 2023-2024  2024/25
#
#  [423 rows x 16 columns],
#  'Serie A 2023-2024':        Wk  Day        Date   Time           Home   xG Score  xG.1  \
#  0     1.0  Sat  2023-08-19  18:30         Empoli  0.7   0–1   0.5
#  1     1.0  Sat  2023-08-19  18:30      Frosinone  0.9   1–3   1.5
#  2     1.0  Sat  2023-08-19  20:45          Genoa  0.2   1–4   1.0
#  3     1.0  Sat  2023-08-19  20:45          Inter  2.7   2–0   0.8
#  4     1.0  Sun  2023-08-20  18:30           Roma  1.9   2–2   0.1
#  ..    ...  ...         ...    ...            ...  ...   ...   ...
#  417  38.0  Sun  2024-05-26  20:45  Hellas Verona  1.7   2–2   2.4
#  418  38.0  Sun  2024-05-26  20:45         Empoli  2.6   2–1   1.3
#  419  38.0  Sun  2024-05-26  20:45          Lazio  1.0   1–1   1.1
#  420   NaN  NaN         NaN    NaN            NaN  NaN   NaN   NaN
#  421  29.0  Sun  2024-06-02  18:00       Atalanta  1.7   2–3   1.2
#
#                Away  Attendance                           Venue  \
#  0    Hellas Verona      7940.0         Stadio Carlo Castellani
#  1           Napoli     15822.0            Stadio Benito Stirpe
#  2       Fiorentina     33045.0  Stadio Comunale Luigi Ferraris
#  3            Monza     72509.0          Stadio Giuseppe Meazza
#  4      Salernitana     62050.0                 Stadio Olimpico
#  ..             ...         ...                             ...
#  417          Inter     22447.0   Stadio Marc'Antonio Bentegodi
#  418           Roma     15896.0         Stadio Carlo Castellani
#  419       Sassuolo     56000.0                 Stadio Olimpico
#  420            NaN         NaN                             NaN
#  421     Fiorentina     14851.0                  Gewiss Stadium
#
#                 Referee  Match Report  Notes             League   Season
#  0         Luca Massimi  Match Report    NaN  Serie A 2023-2024  2024/25
#  1     Matteo Marcenaro  Match Report    NaN  Serie A 2023-2024  2024/25
#  2     Giovanni Ayroldi  Match Report    NaN  Serie A 2023-2024  2024/25
#  3       Andrea Colombo  Match Report    NaN  Serie A 2023-2024  2024/25
#  4    Ermanno Feliciani  Match Report    NaN  Serie A 2023-2024  2024/25
#  ..                 ...           ...    ...                ...      ...
#  417      Luca Zufferli  Match Report    NaN  Serie A 2023-2024  2024/25
#  418       Davide Massa  Match Report    NaN  Serie A 2023-2024  2024/25
#  419   Paride Tremolada  Match Report    NaN  Serie A 2023-2024  2024/25
#  420                NaN           NaN    NaN  Serie A 2023-2024  2024/25
#  421     Daniele Orsato  Match Report    NaN  Serie A 2023-2024  2024/25
#
#  [422 rows x 16 columns],
#  'Bundesliga 2022-2023':                                          Round    Wk  Day        Date   Time  \
#  0                                   Bundesliga   1.0  Fri  2022-08-05  20:30
#  1                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  2                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  3                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  4                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  ..                                         ...   ...  ...         ...    ...
#  337                                 Bundesliga  34.0  Sat  2023-05-27  15:30
#  338                                 Bundesliga  34.0  Sat  2023-05-27  15:30
#  339                                        NaN   NaN  NaN         NaN    NaN
#  340  German 1/2 Relegation/Promotion play-offs   NaN  Thu  2023-06-01  20:45
#  341  German 1/2 Relegation/Promotion play-offs   NaN  Mon  2023-06-05  20:45
#
#                 Home   xG Score  xG.1           Away  Attendance  \
#  0    Eint Frankfurt  0.9   1–6   4.0  Bayern Munich     51500.0
#  1          Augsburg  0.7   0–4   1.2       Freiburg     25310.0
#  2         Wolfsburg  1.0   2–2   0.8  Werder Bremen     28015.0
#  3            Bochum  0.9   1–2   1.4       Mainz 05     24110.0
#  4          Gladbach  1.9   3–1   0.1     Hoffenheim     49659.0
#  ..              ...  ...   ...   ...            ...         ...
#  337  Eint Frankfurt  2.1   2–1   1.6       Freiburg     50500.0
#  338        Dortmund  4.0   2–2   1.8       Mainz 05     81365.0
#  339             NaN  NaN   NaN   NaN            NaN         NaN
#  340       Stuttgart  NaN   3–0   NaN   Hamburger SV     48500.0
#  341    Hamburger SV  NaN   1–3   NaN      Stuttgart     55500.0
#
#                          Venue           Referee  Match Report  \
#  0          Deutsche Bank Park     Deniz Aytekin  Match Report
#  1                   WWK Arena   Bastian Dankert  Match Report
#  2            Volkswagen Arena  Sascha Stegemann  Match Report
#  3         Vonovia Ruhrstadion      Felix Zwayer  Match Report
#  4    Stadion im Borussia-Park    Daniel Siebert  Match Report
#  ..                        ...               ...           ...
#  337        Deutsche Bank Park     Deniz Aytekin  Match Report
#  338         Signal Iduna Park       Marco Fritz  Match Report
#  339                       NaN               NaN           NaN
#  340                  MHPArena       Tobias Welz  Match Report
#  341          Volksparkstadion   Bastian Dankert  Match Report
#
#                           Notes                League   Season
#  0                          NaN  Bundesliga 2022-2023  2024/25
#  1                          NaN  Bundesliga 2022-2023  2024/25
#  2                          NaN  Bundesliga 2022-2023  2024/25
#  3                          NaN  Bundesliga 2022-2023  2024/25
#  4                          NaN  Bundesliga 2022-2023  2024/25
#  ..                         ...                   ...      ...
#  337                        NaN  Bundesliga 2022-2023  2024/25
#  338                        NaN  Bundesliga 2022-2023  2024/25
#  339                        NaN  Bundesliga 2022-2023  2024/25
#  340                 Leg 1 of 2  Bundesliga 2022-2023  2024/25
#  341  Leg 2 of 2; Stuttgart won  Bundesliga 2022-2023  2024/25
#
#  [342 rows x 17 columns],
#  'Premier League 2022-2023':        Wk  Day        Date   Time            Home   xG Score  xG.1  \
#  0     1.0  Fri  2022-08-05  20:00  Crystal Palace  1.2   0–2   1.0
#  1     1.0  Sat  2022-08-06  12:30          Fulham  1.2   2–2   1.2
#  2     1.0  Sat  2022-08-06  15:00   Newcastle Utd  1.7   2–0   0.3
#  3     1.0  Sat  2022-08-06  15:00     Bournemouth  0.6   2–0   0.7
#  4     1.0  Sat  2022-08-06  15:00    Leeds United  0.8   2–1   1.3
#  ..    ...  ...         ...    ...             ...  ...   ...   ...
#  425  38.0  Sun  2023-05-28  16:30     Aston Villa  2.8   2–1   1.4
#  426  38.0  Sun  2023-05-28  16:30    Leeds United  1.5   1–4   2.2
#  427  38.0  Sun  2023-05-28  16:30         Arsenal  2.8   5–0   0.5
#  428  38.0  Sun  2023-05-28  16:30  Manchester Utd  2.9   2–1   1.8
#  429  38.0  Sun  2023-05-28  16:30         Chelsea  2.2   1–1   1.7
#
#                  Away  Attendance             Venue         Referee  \
#  0            Arsenal     25286.0     Selhurst Park  Anthony Taylor
#  1          Liverpool     22207.0    Craven Cottage     Andy Madley
#  2    Nott'ham Forest     52245.0    St James' Park    Simon Hooper
#  3        Aston Villa     11013.0  Vitality Stadium    Peter Bankes
#  4             Wolves     36347.0       Elland Road    Robert Jones
#  ..               ...         ...               ...             ...
#  425         Brighton         NaN        Villa Park     David Coote
#  426        Tottenham     36871.0       Elland Road  Anthony Taylor
#  427           Wolves     60095.0  Emirates Stadium  Andre Marriner
#  428           Fulham     73465.0      Old Trafford    Robert Jones
#  429    Newcastle Utd     40130.0   Stamford Bridge  Jarred Gillett
#
#       Match Report  Notes                    League   Season
#  0    Match Report    NaN  Premier League 2022-2023  2024/25
#  1    Match Report    NaN  Premier League 2022-2023  2024/25
#  2    Match Report    NaN  Premier League 2022-2023  2024/25
#  3    Match Report    NaN  Premier League 2022-2023  2024/25
#  4    Match Report    NaN  Premier League 2022-2023  2024/25
#  ..            ...    ...                       ...      ...
#  425  Match Report    NaN  Premier League 2022-2023  2024/25
#  426  Match Report    NaN  Premier League 2022-2023  2024/25
#  427  Match Report    NaN  Premier League 2022-2023  2024/25
#  428  Match Report    NaN  Premier League 2022-2023  2024/25
#  429  Match Report    NaN  Premier League 2022-2023  2024/25
#
#  [430 rows x 16 columns],
#  'Serie A 2022-2023':                       Round    Wk  Day        Date   Time        Home   xG  \
#  0                   Serie A   1.0  Sat  2022-08-13  18:30       Milan  2.3
#  1                   Serie A   1.0  Sat  2022-08-13  18:30   Sampdoria  1.0
#  2                   Serie A   1.0  Sat  2022-08-13  20:45       Lecce  0.7
#  3                   Serie A   1.0  Sat  2022-08-13  20:45       Monza  1.4
#  4                   Serie A   1.0  Sun  2022-08-14  18:30  Fiorentina  2.0
#  ..                      ...   ...  ...         ...    ...         ...  ...
#  414                 Serie A  38.0  Sun  2023-06-04  21:00     Udinese  0.8
#  415                 Serie A  38.0  Sun  2023-06-04  21:00       Milan  2.4
#  416                 Serie A  38.0  Sun  2023-06-04  21:00    Atalanta  4.0
#  417                     NaN   NaN  NaN         NaN    NaN         NaN  NaN
#  418  Relegation tie-breaker   NaN  Sun  2023-06-11  20:45      Spezia  1.9
#
#      Score  xG.1           Away  Attendance                           Venue  \
#  0     4–2   0.5        Udinese     70197.0          Stadio Giuseppe Meazza
#  1     0–2   2.2       Atalanta     20047.0  Stadio Comunale Luigi Ferraris
#  2     1–2   2.1          Inter     25353.0    Stadio Comunale Via Del Mare
#  3     1–2   2.1         Torino     10739.0                 U-Power Stadium
#  4     3–2   1.3      Cremonese     34461.0          Stadio Artemio Franchi
#  ..    ...   ...            ...         ...                             ...
#  414   0–1   1.3       Juventus     23266.0                     Dacia Arena
#  415   3–1   0.8  Hellas Verona     72102.0          Stadio Giuseppe Meazza
#  416   5–2   1.2          Monza     19389.0                  Gewiss Stadium
#  417   NaN   NaN            NaN         NaN                             NaN
#  418   1–3   0.8  Hellas Verona         NaN                     Dacia Arena
#
#                   Referee  Match Report  Notes             League   Season
#  0        Livio Marinelli  Match Report    NaN  Serie A 2022-2023  2024/25
#  1       Federico Dionisi  Match Report    NaN  Serie A 2022-2023  2024/25
#  2    Alessandro Prontera  Match Report    NaN  Serie A 2022-2023  2024/25
#  3       Maurizio Mariani  Match Report    NaN  Serie A 2022-2023  2024/25
#  4            Juan Sacchi  Match Report    NaN  Serie A 2022-2023  2024/25
#  ..                   ...           ...    ...                ...      ...
#  414          Marco Guida  Match Report    NaN  Serie A 2022-2023  2024/25
#  415         Paolo Valeri  Match Report    NaN  Serie A 2022-2023  2024/25
#  416       Marco Di Bello  Match Report    NaN  Serie A 2022-2023  2024/25
#  417                  NaN           NaN    NaN  Serie A 2022-2023  2024/25
#  418       Daniele Orsato  Match Report    NaN  Serie A 2022-2023  2024/25
#
#  [419 rows x 17 columns]}

# %%
Serie_A_22_23 = df["Serie A 2022-2023"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\JMerilien\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Serie A 2022-2023'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 Serie_A_22_23 = df["Serie A 2022-2023"]
#
# File c:\Users\JMerilien\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\JMerilien\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Serie A 2022-2023'
