# %%
from scrape_stats_function import combine_data
import requests
from bs4 import BeautifulSoup, Comment
from urllib.parse import urlparse
import time
years = ["2024-2025"]
BASE = "https://fbref.com"

# Example: Premier League 2023-2024 season
url = "https://fbref.com/en/comps/9/2023-2024/stats/2023-2024-Premier-League-Stats"
standard_url = [
    {
        "name": "Bundesliga",
        "url": "https://fbref.com/en/comps/20/{year}/stats/{year}-Bundesliga-Stats"
    },
    {
        "name": "Premier League",
        "url": "https://fbref.com/en/comps/9/{year}/stats/{year}-Premier-League-Stats"
    },
    {
        "name": "La Liga",
        "url": "https://fbref.com/en/comps/12/{year}/stats/{year}-La-Liga-Stats"
    },
    {
        "name": "Serie A",
        "url": "https://fbref.com/en/comps/11/{year}/stats/{year}-Serie-A-Stats"
    },
    {
        "name": "Ligue 1",
        "url": "https://fbref.com/en/comps/13/{year}/stats/{year}-Ligue-1-Stats"
    },
    {
        "name": "Eredivisie",
        "url": "https://fbref.com/en/comps/23/{year}/stats/{year}-Eredivisie-Stats"
    },
    {
        "name": "Primeira Liga",
        "url": "https://fbref.com/en/comps/32/{year}/stats/{year}-Primeira-Liga-Stats"
    },
    {
        "name": "Championship",
        "url": "https://fbref.com/en/comps/10/{year}/stats/{year}-EFL-Championship-Stats"
    },
    {
        "name": "Scottish Premiership",
        "url": "https://fbref.com/en/comps/40/{year}/stats/{year}-Scottish-Premiership-Stats"
    }
 
]

def create_links(years, leagues):
    links = []
    for league in leagues:
        for year in years:
            url = league["url"].format(year=year)
            name = league["name"]
            links.append(url)
    return links

links =create_links(years, standard_url)
print(links)
headers = {"User-Agent": "Mozilla/5.0"}

player_links = []  

for link in links:

    res = requests.get(link, headers=headers, verify=False)
    soup = BeautifulSoup(res.text, "html.parser")

    # The player stats table
    try: 
        table_id = "stats_standard"
        table = soup.find("table", id = table_id)

        if not table:
            for comment in soup.find_all(string = lambda text: isinstance(text, Comment)):
                if table_id in comment: 
                    print(f"found {table_id} for {link}")
                    comment_soup = BeautifulSoup(comment, 'html.parser')
                    table = comment_soup.find("table", id=table_id)
                if table: 
                    break
        if table:
            links_found = [BASE + a["href"] for a in table.select("td[data-stat='player'] a")]
            player_links.extend(links_found)

    except KeyboardInterrupt:
        print("Process interrupted by user.")
    time.sleep(5)
        

print(player_links[:5])
# Out:
# ['https://fbref.com/en/comps/20/2024-2025/stats/2024-2025-Bundesliga-Stats', 'https://fbref.com/en/comps/9/2024-2025/stats/2024-2025-Premier-League-Stats', 'https://fbref.com/en/comps/12/2024-2025/stats/2024-2025-La-Liga-Stats', 'https://fbref.com/en/comps/11/2024-2025/stats/2024-2025-Serie-A-Stats', 'https://fbref.com/en/comps/13/2024-2025/stats/2024-2025-Ligue-1-Stats', 'https://fbref.com/en/comps/23/2024-2025/stats/2024-2025-Eredivisie-Stats', 'https://fbref.com/en/comps/32/2024-2025/stats/2024-2025-Primeira-Liga-Stats', 'https://fbref.com/en/comps/10/2024-2025/stats/2024-2025-EFL-Championship-Stats', 'https://fbref.com/en/comps/40/2024-2025/stats/2024-2025-Scottish-Premiership-Stats']
# found stats_standard for https://fbref.com/en/comps/20/2024-2025/stats/2024-2025-Bundesliga-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/9/2024-2025/stats/2024-2025-Premier-League-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/12/2024-2025/stats/2024-2025-La-Liga-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/11/2024-2025/stats/2024-2025-Serie-A-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/13/2024-2025/stats/2024-2025-Ligue-1-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/23/2024-2025/stats/2024-2025-Eredivisie-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/32/2024-2025/stats/2024-2025-Primeira-Liga-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/10/2024-2025/stats/2024-2025-EFL-Championship-Stats
# c:\Users\james\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fbref.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# found stats_standard for https://fbref.com/en/comps/40/2024-2025/stats/2024-2025-Scottish-Premiership-Stats
# ['https://fbref.com/en/players/82e12fe7/Junior-Adamu', 'https://fbref.com/en/players/501055d8/Karim-Adeyemi', 'https://fbref.com/en/players/dcfb17f4/Amine-Adli', 'https://fbref.com/en/players/5054c359/Oladapo-Afolayan', 'https://fbref.com/en/players/cb6d81b3/Felix-Agu']

# %%
print(standard_url[2])
# Out:
# {'name': 'La Liga', 'url': 'https://fbref.com/en/comps/12/{year}/stats/{year}-La-Liga-Stats'}

# %%
print(f"Total player links found: {len(player_links)}")
print(player_links)
# Out:
# Total player links found: 5110
# ['https://fbref.com/en/players/82e12fe7/Junior-Adamu', 'https://fbref.com/en/players/501055d8/Karim-Adeyemi', 'https://fbref.com/en/players/dcfb17f4/Amine-Adli', 'https://fbref.com/en/players/5054c359/Oladapo-Afolayan', 'https://fbref.com/en/players/cb6d81b3/Felix-Agu', 'https://fbref.com/en/players/f6b692c0/Erik-Ahlstrand', 'https://fbref.com/en/players/6ec6fde0/Kevin-Akpoguma', 'https://fbref.com/en/players/94471fb7/Andreas-Albers', 'https://fbref.com/en/players/ee8ad906/Ben-Alexander-Voll', 'https://fbref.com/en/players/add37c13/Skelly-Alvero', 'https://fbref.com/en/players/1227a22d/Aurele-Amenda', 'https://fbref.com/en/players/555d5edd/Nadiem-Amiri', 'https://fbref.com/en/players/6597f8b6/Mohamed-Amoura', 'https://fbref.com/en/players/e0b113a7/Robert-Andrich', 'https://fbref.com/en/players/5e66fa06/Waldemar-Anton', 'https://fbref.com/en/players/86e119e0/Maximilian-Arnold', 'https://fbref.com/en/players/c21fb312/Jann-Fiete-Arp', 'https://fbref.com/en/players/8a958856/Arthur', 'https://fbref.com/en/players/dbd1b101/Noah-Atubolu', 'https://fbref.com/en/players/ce81d82d/Ayman-Azhil', 'https://fbref.com/en/players/e678d983/Adam-Aznou', 'https://fbref.com/en/players/7362a6f2/Aliou-Badara-Balde', 'https://fbref.com/en/players/442b56fa/Ridle-Baku', 'https://fbref.com/en/players/442b56fa/Ridle-Baku', 'https://fbref.com/en/players/489d4867/Samuel-Bamba', 'https://fbref.com/en/players/118e3ac3/Noahkai-Banks', 'https://fbref.com/en/players/d01f8942/Scott-Banks', 'https://fbref.com/en/players/a2a85828/Aymen-Barkok', 'https://fbref.com/en/players/2973d8ff/Michy-Batshuayi', 'https://fbref.com/en/players/44a20f0c/Maximilian-Bauer', 'https://fbref.com/en/players/47064058/Oliver-Baumann', 'https://fbref.com/en/players/437f2b00/Christoph-Baumgartner', 'https://fbref.com/en/players/a53b661f/Ihlas-Bebou', 'https://fbref.com/en/players/616c09f5/Adrian-Beck', 'https://fbref.com/en/players/543ddcaf/Timo-Becker', 'https://fbref.com/en/players/ca788298/Hannes-Behrens', 'https://fbref.com/en/players/30ae134d/Kevin-Behrens', 'https://fbref.com/en/players/5db45ee5/Maximilian-Beier', 'https://fbref.com/en/players/857a5abe/Stefan-Bell', 'https://fbref.com/en/players/c678ddd7/Jeanuel-Belocian', 'https://fbref.com/en/players/fe888e39/Laszlo-Benes', 'https://fbref.com/en/players/378825c7/Ramy-Bensebaini', 'https://fbref.com/en/players/eb6e14be/Mergim-Berisha', 'https://fbref.com/en/players/eb6e14be/Mergim-Berisha', 'https://fbref.com/en/players/17370b95/Bernardo', 'https://fbref.com/en/players/dea1d183/Alexander-Bernhardsson', 'https://fbref.com/en/players/b5e0af76/Matus-Bero', 'https://fbref.com/en/players/57382429/Jan-Niklas-Beste', 'https://fbref.com/en/players/47c609d5/El-Bilal-Toure', 'https://fbref.com/en/players/07d3bfec/Tom-Bischof', 'https://fbref.com/en/players/dc62fbee/Leonardo-Bittencourt', 'https://fbref.com/en/players/5b479568/Myron-Boadu', 'https://fbref.com/en/players/6c8ddd52/Sacha-Boey', 'https://fbref.com/en/players/b146275b/Victor-Boniface', 'https://fbref.com/en/players/01834aa0/Sebastiaan-Bornauw', 'https://fbref.com/en/players/1a86f4a9/Carlo-Boukhalfa', 'https://fbref.com/en/players/a167537f/Julian-Brandt', 'https://fbref.com/en/players/ed98c321/Tim-Breithaupt', 'https://fbref.com/en/players/1e37c986/Maximilian-Breunig', 'https://fbref.com/en/players/bbd79358/Moritz-Broschinski', 'https://fbref.com/en/players/abc79c47/Nathaniel-Brown', 'https://fbref.com/en/players/4e204552/Jacob-Bruun-Larsen', 'https://fbref.com/en/players/4e204552/Jacob-Bruun-Larsen', 'https://fbref.com/en/players/66b76d44/Emi-Buendia', 'https://fbref.com/en/players/ab5b7dc1/Marius-Bulter', 'https://fbref.com/en/players/05f99a4a/Jonathan-Burkardt', 'https://fbref.com/en/players/f631c17f/Oliver-Burke', 'https://fbref.com/en/players/c38767ab/Marnon-Busch', 'https://fbref.com/en/players/0118c54c/Anthony-Caci', 'https://fbref.com/en/players/fbb270b2/Cole-Campbell', 'https://fbref.com/en/players/a65ce836/Emre-Can', 'https://fbref.com/en/players/79268b9c/Tiago-Cardoso',  ...

# %%
def make_matchlog_links(player_urls, years):
    links = []
    for url in player_urls:
        parts = url.strip("/").split("/")
        player_id = parts[-2]      # "dea698d9"
        player_slug = parts[-1]    # "Erling-Haaland"
        
        for year in years:   
            matchlog_url = f"https://fbref.com/en/players/{player_id}/matchlogs/{year}/{player_slug}-Match-Logs"
            links.append({
                "name": f"[{player_slug} - {year}]",
                "url": matchlog_url})
    return links

general_matchlog_links = []
general_matchlog_links = make_matchlog_links(player_links, years)

#print(general_matchlog_links)

match_logs = []
match_logs = combine_data(years, general_matchlog_links, table_id='matchlogs_all')
# Out:
# 200 https://fbref.com/en/players/82e12fe7/matchlogs/2024-2025/Junior-Adamu-Match-Logs
# 200 https://fbref.com/en/players/501055d8/matchlogs/2024-2025/Karim-Adeyemi-Match-Logs
# 200 https://fbref.com/en/players/dcfb17f4/matchlogs/2024-2025/Amine-Adli-Match-Logs
# 200 https://fbref.com/en/players/5054c359/matchlogs/2024-2025/Oladapo-Afolayan-Match-Logs
# Scraping interrupted

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
matchlogs_df = pd.concat(match_logs, ignore_index=True)
matchlogs_df.tail()
# Out:
#            Date  Day        Comp         Round Venue  Result      Squad  \
# 157  2025-04-27  Sun  Bundesliga  Matchweek 31  Away   D 0–0  St. Pauli
# 158  2025-05-03  Sat  Bundesliga  Matchweek 32  Home   L 0–1  St. Pauli
# 159  2025-05-11  Sun  Bundesliga  Matchweek 33  Away   D 2–2  St. Pauli
# 160  2025-05-17  Sat  Bundesliga  Matchweek 34  Home   L 0–2  St. Pauli
# 161         NaN  NaN         NaN           NaN   NaN  9-7-18        NaN
#
#            Opponent  Start                                  Pos  \
# 157   Werder Bremen      N  On matchday squad, but did not play
# 158       Stuttgart      N                                FW,LM
# 159  Eint Frankfurt      Y                                   AM
# 160          Bochum      Y                                   LW
# 161             NaN  18/34                                  NaN
#
#                                      Min                                  Gls  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                   28                                    0
# 159                                   75                                    0
# 160                                   45                                    0
# 161                                 1767                                    3
#
#                                      Ast                                   PK  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    0                                    0
# 159                                    0                                    0
# 160                                    0                                    0
# 161                                    1                                    0
#
#                                    PKatt                                   Sh  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    0                                    0
# 159                                    0                                    1
# 160                                    0                                    3
# 161                                    0                                   40
#
#                                      SoT                                 CrdY  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    0                                    0
# 159                                    0                                    0
# 160                                    1                                    0
# 161                                   14                                    3
#
#                                     CrdR                              Touches  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    0                                   10
# 159                                    0                                   17
# 160                                    0                                   32
# 161                                    0                                  741
#
#                                      Tkl                                  Int  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    0                                    0
# 159                                    1                                    0
# 160                                    0                                    0
# 161                                   17                                    8
#
#                                   Blocks                                   xG  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    1                                  0.0
# 159                                    0                                  0.0
# 160                                    1                                  0.2
# 161                                   17                                  3.1
#
#                                     npxG                                  xAG  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                  0.0                                  0.0
# 159                                  0.0                                  0.0
# 160                                  0.2                                  0.1
# 161                                  3.1                                  3.8
#
#                                      SCA                                  GCA  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    0                                    0
# 159                                    0                                    0
# 160                                    3                                    0
# 161                                   52                                    6
#
#                                      Cmp                                  Att  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    0                                    5
# 159                                    5                                    7
# 160                                   14                                   21
# 161                                  320                                  461
#
#                                     Cmp%                                 PrgP  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                  0.0                                    0
# 159                                 71.4                                    2
# 160                                 66.7                                    0
# 161                                 69.4                                   32
#
#                                  Carries                                 PrgC  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    5                                    0
# 159                                   12                                    1
# 160                                   25                                    1
# 161                                  495                                   53
#
#                                    Att.1                                 Succ  \
# 157  On matchday squad, but did not play  On matchday squad, but did not play
# 158                                    2                                    1
# 159                                    2                                    1
# 160                                    2                                    0
# 161                                   98                                   48
#
#      Match Report                                    League
# 157  Match Report  [Oladapo-Afolayan - 2024-2025] 2024-2025
# 158  Match Report  [Oladapo-Afolayan - 2024-2025] 2024-2025
# 159  Match Report  [Oladapo-Afolayan - 2024-2025] 2024-2025
# 160  Match Report  [Oladapo-Afolayan - 2024-2025] 2024-2025
# 161           NaN  [Oladapo-Afolayan - 2024-2025] 2024-2025
