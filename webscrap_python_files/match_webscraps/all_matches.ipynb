# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import warnings

def scrape_league_data(league_name, url, table_id=None, season="2024/25"):
    warnings.filterwarnings("ignore")
    print(f"Scraping {league_name}...")

    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers, verify=False)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", id=table_id) if table_id else soup.find("table")
    if not table:
        print(f"Table not found for {league_name}")
        return None

    df = pd.read_html(str(table))[0]
    df['League'] = league_name
    df['Season'] = season

    return df

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup, Comment
import warnings

def scrape_league_data(league_name, url, table_id=None, season="2024/25"):
    warnings.filterwarnings("ignore")
    print(f"Scraping {league_name}...")

    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers, verify=False)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", id="stats_squads_standard_for") if table_id else soup.find("table")
    if not table:
        # If not found, look inside HTML comments
        for comment in soup.find_all(string=lambda text: isinstance(text, Comment)):
            comment_soup = BeautifulSoup(comment, 'html.parser')
            table = comment_soup.find("table", id="stats_squads_standard_for") if table_id else comment_soup.find("table")
            if table:
                break

    if not table:
        print(f"Table not found for {league_name}")
        return None

    df = pd.read_html(str(table))[0]
    df['League'] = league_name
    df['Season'] = season

    return df

# %%
# List of leagues to scrape
years = ["2024-2025","2023-2024","2022-2023","2021-2022","2020-2021","2019-2020","2018-2019","2017-2018","2016-2017","2015-2016"]
leagueinfo = [
    {
        "name": "Bundesliga",
        "url": "https://fbref.com/en/comps/20/{year}/schedule/{year}-Bundesliga-Scores-and-Fixtures"

    },
    {
        "name": "Premier League",
        "url": "https://fbref.com/en/comps/9/{year}/schedule/{year}-Premier-League-Scores-and-Fixtures"
    },
    {
        "name": "Serie A",
        "url": "https://fbref.com/en/comps/11/{year}/schedule/{year}-Serie-A-Scores-and-Fixtures"
    }
    ,
    {
        "name": "La Liga",
        "url": "https://fbref.com/en/comps/12/{year}/schedule/{year}-La-Liga-Scores-and-Fixtures"
    },
    {
        "name": "Ligue 1",
        "url": "https://fbref.com/en/comps/13/{year}/schedule/{year}-Ligue-1-Scores-and-Fixtures"
    },
    {
        "name": "Eredivisie",
        "url": "https://fbref.com/en/comps/20/{year}/schedule/{year}-Eredivisie-Scores-and-Fixtures"
    },
    {
        "name": "Primeira Liga",
        "url": "https://fbref.com/en/comps/19/{year}/schedule/{year}-Primeira-Liga-Scores-and-Fixtures"
    },
    {
        "name": "EFL Championship",
        "url": "https://fbref.com/en/comps/10/{year}/schedule/{year}-EFL-Championship-Scores-and-Fixtures"
    }

]

leagues = []
for year in years:
    for league in leagueinfo:
        leagues.append({
            "name": f"{league['name']} {year}",
            "url": league["url"].format(year=year),
            "season": year.replace("-", "/")
        })

league_dfs = {}
combined_list = []

for league in leagues:
    df = scrape_league_data(league["name"], league["url"])
    if df is not None:
        league_dfs[league["name"]] = df 
        combined_list.append(df)
# [                                         Round    Wk  Day        Date   Time  \
#  0                                   Bundesliga   1.0  Fri  2022-08-05  20:30
#  1                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  2                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  3                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  4                                   Bundesliga   1.0  Sat  2022-08-06  15:30
#  ..                                         ...   ...  ...         ...    ...
#  337                                 Bundesliga  34.0  Sat  2023-05-27  15:30
#  338                                 Bundesliga  34.0  Sat  2023-05-27  15:30
#  339                                        NaN   NaN  NaN         NaN    NaN
#  340  German 1/2 Relegation/Promotion play-offs   NaN  Thu  2023-06-01  20:45
#  341  German 1/2 Relegation/Promotion play-offs   NaN  Mon  2023-06-05  20:45
#
#                 Home   xG Score  xG.1           Away  Attendance  \
#  0    Eint Frankfurt  0.9   1–6   4.0  Bayern Munich     51500.0
#  1          Augsburg  0.7   0–4   1.2       Freiburg     25310.0
#  2         Wolfsburg  1.0   2–2   0.8  Werder Bremen     28015.0
#  3            Bochum  0.9   1–2   1.4       Mainz 05     24110.0
#  4          Gladbach  1.9   3–1   0.1     Hoffenheim     49659.0
#  ..              ...  ...   ...   ...            ...         ...
#  337  Eint Frankfurt  2.1   2–1   1.6       Freiburg     50500.0
#  338        Dortmund  4.0   2–2   1.8       Mainz 05     81365.0
#  339             NaN  NaN   NaN   NaN            NaN         NaN
#  340       Stuttgart  NaN   3–0   NaN   Hamburger SV     48500.0
#  341    Hamburger SV  NaN   1–3   NaN      Stuttgart     55500.0
#
#                          Venue           Referee  Match Report  \
#  0          Deutsche Bank Park     Deniz Aytekin  Match Report
#  1                   WWK Arena   Bastian Dankert  Match Report
#  2            Volkswagen Arena  Sascha Stegemann  Match Report
#  3         Vonovia Ruhrstadion      Felix Zwayer  Match Report
#  4    Stadion im Borussia-Park    Daniel Siebert  Match Report
#  ..                        ...               ...           ...
#  337        Deutsche Bank Park     Deniz Aytekin  Match Report
#  338         Signal Iduna Park       Marco Fritz  Match Report
#  339                       NaN               NaN           NaN
#  340                  MHPArena       Tobias Welz  Match Report
#  341          Volksparkstadion   Bastian Dankert  Match Report
#
#                           Notes                League   Season
#  0                          NaN  Bundesliga 2022-2023  2024/25
#  1                          NaN  Bundesliga 2022-2023  2024/25
#  2                          NaN  Bundesliga 2022-2023  2024/25
#  3                          NaN  Bundesliga 2022-2023  2024/25
#  4                          NaN  Bundesliga 2022-2023  2024/25
#  ..                         ...                   ...      ...
#  337                        NaN  Bundesliga 2022-2023  2024/25
#  338                        NaN  Bundesliga 2022-2023  2024/25
#  339                        NaN  Bundesliga 2022-2023  2024/25
#  340                 Leg 1 of 2  Bundesliga 2022-2023  2024/25
#  341  Leg 2 of 2; Stuttgart won  Bundesliga 2022-2023  2024/25
#
#  [342 rows x 17 columns],
#             Round   Wk  Day        Date   Time               Home   xG  \
#
#  [213 rows x 17 columns],
#             Round   Wk  Day        Date   Time                Home Score  \
#  0    Group stage    1  Thu  2016-09-15  19:00       Anderlecht be   3–1
#  1    Group stage    1  Thu  2016-09-15  19:00         Mainz 05 de   1–1
#  2    Group stage    1  Thu  2016-09-15  19:00       AZ Alkmaar nl   1–1
#  3    Group stage    1  Thu  2016-09-15  19:00       Rapid Wien at   3–2
#  4    Group stage    1  Thu  2016-09-15  19:00         Sassuolo it   3–0
#  ..           ...  ...  ...         ...    ...                 ...   ...
#  208  Semi-finals  NaN  Wed  2017-05-03  18:45             Ajax nl   4–1
#  209  Semi-finals  NaN  Thu  2017-05-04  21:05       Celta Vigo es   0–1
#  210  Semi-finals  NaN  Thu  2017-05-11  20:05  Manchester Utd eng   1–1
#  211  Semi-finals  NaN  Thu  2017-05-11  21:05             Lyon fr   3–1
#  212        Final  NaN  Wed  2017-05-24  20:45             Ajax nl   0–2
#
#                     Away Attendance                         Venue  \
#  0             az Qabala      11638   Stade Constant Vanden Stock
#  1      fr Saint-Étienne      20275                    Opel Arena
#  2         ie Dundalk FC      10003                  AFAS Stadion
#  3               be Genk      21800               Allianz Stadion
#  4      es Athletic Club       7032    Stadio Città del Tricolore
#  ..                  ...        ...                           ...
#  208             fr Lyon      52141            Johan Cruyff ArenA
#  209  eng Manchester Utd      26202           Estadio de Balaídos
#  210       es Celta Vigo      75138                  Old Trafford
#  211             nl Ajax      53810              Groupama Stadium
#  212  eng Manchester Utd      46961  Friends Arena (Neutral Site)
#
#                 Referee  Match Report                           Notes  \
#  0       Harald Lechner  Match Report                             NaN
#  1    Svein Oddvar Moen  Match Report                             NaN
#  2       Clayton Pisani  Match Report                             NaN
#  3           Kevin Blom  Match Report                             NaN
#  4     Paweł Raczkowski  Match Report                             NaN
#  ..                 ...           ...                             ...
#  208    Gianluca Rocchi  Match Report                      Leg 1 of 2
#  209     Sergey Karasev  Match Report                      Leg 1 of 2
#  210     Ovidiu Hațegan  Match Report  Leg 2 of 2; Manchester Utd won
#  211   Szymon Marciniak  Match Report            Leg 2 of 2; Ajax won
#  212      Damir Skomina  Match Report                             NaN
#
#                        League   Season
#  0    Primeira Liga 2016-2017  2024/25
#  1    Primeira Liga 2016-2017  2024/25
#  2    Primeira Liga 2016-2017  2024/25
#  3    Primeira Liga 2016-2017  2024/25
#  4    Primeira Liga 2016-2017  2024/25
#  ..                       ...      ...
#  208  Primeira Liga 2016-2017  2024/25
#  209  Primeira Liga 2016-2017  2024/25
#  210  Primeira Liga 2016-2017  2024/25
#  211  Primeira Liga 2016-2017  2024/25
#  212  Primeira Liga 2016-2017  2024/25
#
#  [213 rows x 15 columns]]

# %%
df = pd.concat(combined_list, ignore_index=True)
df['League'].unique()
# Out:
# array(['Bundesliga 2022-2023', 'Primeira Liga 2018-2019',
#        'Primeira Liga 2016-2017'], dtype=object)
