# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

def scrape_league_data(league_name, url, table_id=None, season="2024/25"):
    print(f"Scraping {league_name}...")

    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers, verify=False)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", id=table_id) if table_id else soup.find("table")
    if not table:
        print(f"Table not found for {league_name}")
        return None

    df = pd.read_html(str(table))[0]
    df['League'] = league_name
    df['Season'] = season

    return df

# %%
# List of leagues to scrape
years = ["2024-2025","2023-2024","2022-2023","2021-2022","2020-2021","2019-2020","2018-2019","2017-2018","2016-2017","2015-2016"]
leagueinfo = [
    {
        "name": "Bundesliga",
        "url": "https://fbref.com/en/comps/20/{year}/schedule/{year}-Bundesliga-Scores-and-Fixtures"

    },
    {
        "name": "Premier League",
        "url": "https://fbref.com/en/comps/9/{year}/schedule/{year}-Premier-League-Scores-and-Fixtures"
    },
    {
        "name": "Serie A",
        "url": "https://fbref.com/en/comps/11/{year}/schedule/{year}-Serie-A-Scores-and-Fixtures"
    }
    ,
    {
        "name": "La Liga",
        "url": "https://fbref.com/en/comps/12/{year}/schedule/{year}-La-Liga-Scores-and-Fixtures"
    },
    {
        "name": "Ligue 1",
        "url": "https://fbref.com/en/comps/13/{year}/schedule/{year}-Ligue-1-Scores-and-Fixtures"
    },
    {
        "name": "Eredivisie",
        "url": "https://fbref.com/en/comps/20/{year}/schedule/{year}-Eredivisie-Scores-and-Fixtures"
    },
    {
        "name": "Primeira Liga",
        "url": "https://fbref.com/en/comps/19/{year}/schedule/{year}-Primeira-Liga-Scores-and-Fixtures"
    },
    {
        "name": "EFL Championship",
        "url": "https://fbref.com/en/comps/10/{year}/schedule/{year}-EFL-Championship-Scores-and-Fixtures"
    }

]

leagues = []
for year in years:
    for league in leagueinfo:
        leagues.append({
            "name": f"{league['name']} {year}",
            "url": league["url"].format(year=year),
            "season": year.replace("-", "/")
        })

league_dfs = {}
combined_list = []

for league in leagues:
    df = scrape_league_data(league["name"], league["url"])
    if df is not None:
        league_dfs[league["name"]] = df 
        combined_list.append(df)

# %%
league_dfs = pd.concat(combined_list, ignore_index=True)
league_dfs.head()
# Out:
#         Round   Wk  Day        Date   Time        Home   xG Score xG.1  \
# 0  Bundesliga  1.0  Fri  2024-08-23  20:30    Gladbach  1.6   2–3  2.7
# 1  Bundesliga  1.0  Sat  2024-08-24  15:30  Hoffenheim  3.5   3–2  1.7
# 2  Bundesliga  1.0  Sat  2024-08-24  15:30    Mainz 05  1.2   1–1  0.6
# 3  Bundesliga  1.0  Sat  2024-08-24  15:30    Augsburg  1.0   2–2  1.4
# 4  Bundesliga  1.0  Sat  2024-08-24  15:30    Freiburg  2.1   3–1  0.4
#
#             Away Attendance                     Venue           Referee  \
# 0     Leverkusen    54042.0  Stadion im Borussia-Park   Robert Schröder
# 1  Holstein Kiel    18503.0             PreZero Arena    Tobias Stieler
# 2   Union Berlin    31500.0                Mewa Arena       Harm Osmers
# 3  Werder Bremen    30660.0                 WWK Arena  Sascha Stegemann
# 4      Stuttgart    34700.0       Europa-Park Stadion       Tobias Welz
#
#    Match Report Notes                League   Season
# 0  Match Report   NaN  Bundesliga 2024-2025  2024/25
# 1  Match Report   NaN  Bundesliga 2024-2025  2024/25
# 2  Match Report   NaN  Bundesliga 2024-2025  2024/25
# 3  Match Report   NaN  Bundesliga 2024-2025  2024/25
# 4  Match Report   NaN  Bundesliga 2024-2025  2024/25

# %%
leagues
# Out:
# [{'name': 'Bundesliga 2024-2025',
#   'url': 'https://fbref.com/en/comps/20/2024-2025/schedule/2024-2025-Bundesliga-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'Premier League 2024-2025',
#   'url': 'https://fbref.com/en/comps/9/2024-2025/schedule/2024-2025-Premier-League-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'Serie A 2024-2025',
#   'url': 'https://fbref.com/en/comps/11/2024-2025/schedule/2024-2025-Serie-A-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'La Liga 2024-2025',
#   'url': 'https://fbref.com/en/comps/12/2024-2025/schedule/2024-2025-La-Liga-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'Ligue 1 2024-2025',
#   'url': 'https://fbref.com/en/comps/13/2024-2025/schedule/2024-2025-Ligue-1-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'Eredivisie 2024-2025',
#   'url': 'https://fbref.com/en/comps/20/2024-2025/schedule/2024-2025-Eredivisie-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'Primeira Liga 2024-2025',
#   'url': 'https://fbref.com/en/comps/19/2024-2025/schedule/2024-2025-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'EFL Championship 2024-2025',
#   'url': 'https://fbref.com/en/comps/10/2024-2025/schedule/2024-2025-EFL-Championship-Scores-and-Fixtures',
#   'season': '2024/2025'},
#  {'name': 'Bundesliga 2023-2024',
#   'url': 'https://fbref.com/en/comps/20/2023-2024/schedule/2023-2024-Bundesliga-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'Premier League 2023-2024',
#   'url': 'https://fbref.com/en/comps/9/2023-2024/schedule/2023-2024-Premier-League-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'Serie A 2023-2024',
#   'url': 'https://fbref.com/en/comps/11/2023-2024/schedule/2023-2024-Serie-A-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'La Liga 2023-2024',
#   'url': 'https://fbref.com/en/comps/12/2023-2024/schedule/2023-2024-La-Liga-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'Ligue 1 2023-2024',
#   'url': 'https://fbref.com/en/comps/13/2023-2024/schedule/2023-2024-Ligue-1-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'Eredivisie 2023-2024',
#   'url': 'https://fbref.com/en/comps/20/2023-2024/schedule/2023-2024-Eredivisie-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'Primeira Liga 2023-2024',
#   'url': 'https://fbref.com/en/comps/19/2023-2024/schedule/2023-2024-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'EFL Championship 2023-2024',
#   'url': 'https://fbref.com/en/comps/10/2023-2024/schedule/2023-2024-EFL-Championship-Scores-and-Fixtures',
#   'season': '2023/2024'},
#  {'name': 'Bundesliga 2022-2023',
#   'url': 'https://fbref.com/en/comps/20/2022-2023/schedule/2022-2023-Bundesliga-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'Premier League 2022-2023',
#   'url': 'https://fbref.com/en/comps/9/2022-2023/schedule/2022-2023-Premier-League-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'Serie A 2022-2023',
#   'url': 'https://fbref.com/en/comps/11/2022-2023/schedule/2022-2023-Serie-A-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'La Liga 2022-2023',
#   'url': 'https://fbref.com/en/comps/12/2022-2023/schedule/2022-2023-La-Liga-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'Ligue 1 2022-2023',
#   'url': 'https://fbref.com/en/comps/13/2022-2023/schedule/2022-2023-Ligue-1-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'Eredivisie 2022-2023',
#   'url': 'https://fbref.com/en/comps/20/2022-2023/schedule/2022-2023-Eredivisie-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'Primeira Liga 2022-2023',
#   'url': 'https://fbref.com/en/comps/19/2022-2023/schedule/2022-2023-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'EFL Championship 2022-2023',
#   'url': 'https://fbref.com/en/comps/10/2022-2023/schedule/2022-2023-EFL-Championship-Scores-and-Fixtures',
#   'season': '2022/2023'},
#  {'name': 'Bundesliga 2021-2022',
#   'url': 'https://fbref.com/en/comps/20/2021-2022/schedule/2021-2022-Bundesliga-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'Premier League 2021-2022',
#   'url': 'https://fbref.com/en/comps/9/2021-2022/schedule/2021-2022-Premier-League-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'Serie A 2021-2022',
#   'url': 'https://fbref.com/en/comps/11/2021-2022/schedule/2021-2022-Serie-A-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'La Liga 2021-2022',
#   'url': 'https://fbref.com/en/comps/12/2021-2022/schedule/2021-2022-La-Liga-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'Ligue 1 2021-2022',
#   'url': 'https://fbref.com/en/comps/13/2021-2022/schedule/2021-2022-Ligue-1-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'Eredivisie 2021-2022',
#   'url': 'https://fbref.com/en/comps/20/2021-2022/schedule/2021-2022-Eredivisie-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'Primeira Liga 2021-2022',
#   'url': 'https://fbref.com/en/comps/19/2021-2022/schedule/2021-2022-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'EFL Championship 2021-2022',
#   'url': 'https://fbref.com/en/comps/10/2021-2022/schedule/2021-2022-EFL-Championship-Scores-and-Fixtures',
#   'season': '2021/2022'},
#  {'name': 'Bundesliga 2020-2021',
#   'url': 'https://fbref.com/en/comps/20/2020-2021/schedule/2020-2021-Bundesliga-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'Premier League 2020-2021',
#   'url': 'https://fbref.com/en/comps/9/2020-2021/schedule/2020-2021-Premier-League-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'Serie A 2020-2021',
#   'url': 'https://fbref.com/en/comps/11/2020-2021/schedule/2020-2021-Serie-A-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'La Liga 2020-2021',
#   'url': 'https://fbref.com/en/comps/12/2020-2021/schedule/2020-2021-La-Liga-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'Ligue 1 2020-2021',
#   'url': 'https://fbref.com/en/comps/13/2020-2021/schedule/2020-2021-Ligue-1-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'Eredivisie 2020-2021',
#   'url': 'https://fbref.com/en/comps/20/2020-2021/schedule/2020-2021-Eredivisie-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'Primeira Liga 2020-2021',
#   'url': 'https://fbref.com/en/comps/19/2020-2021/schedule/2020-2021-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'EFL Championship 2020-2021',
#   'url': 'https://fbref.com/en/comps/10/2020-2021/schedule/2020-2021-EFL-Championship-Scores-and-Fixtures',
#   'season': '2020/2021'},
#  {'name': 'Bundesliga 2019-2020',
#   'url': 'https://fbref.com/en/comps/20/2019-2020/schedule/2019-2020-Bundesliga-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'Premier League 2019-2020',
#   'url': 'https://fbref.com/en/comps/9/2019-2020/schedule/2019-2020-Premier-League-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'Serie A 2019-2020',
#   'url': 'https://fbref.com/en/comps/11/2019-2020/schedule/2019-2020-Serie-A-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'La Liga 2019-2020',
#   'url': 'https://fbref.com/en/comps/12/2019-2020/schedule/2019-2020-La-Liga-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'Ligue 1 2019-2020',
#   'url': 'https://fbref.com/en/comps/13/2019-2020/schedule/2019-2020-Ligue-1-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'Eredivisie 2019-2020',
#   'url': 'https://fbref.com/en/comps/20/2019-2020/schedule/2019-2020-Eredivisie-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'Primeira Liga 2019-2020',
#   'url': 'https://fbref.com/en/comps/19/2019-2020/schedule/2019-2020-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'EFL Championship 2019-2020',
#   'url': 'https://fbref.com/en/comps/10/2019-2020/schedule/2019-2020-EFL-Championship-Scores-and-Fixtures',
#   'season': '2019/2020'},
#  {'name': 'Bundesliga 2018-2019',
#   'url': 'https://fbref.com/en/comps/20/2018-2019/schedule/2018-2019-Bundesliga-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'Premier League 2018-2019',
#   'url': 'https://fbref.com/en/comps/9/2018-2019/schedule/2018-2019-Premier-League-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'Serie A 2018-2019',
#   'url': 'https://fbref.com/en/comps/11/2018-2019/schedule/2018-2019-Serie-A-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'La Liga 2018-2019',
#   'url': 'https://fbref.com/en/comps/12/2018-2019/schedule/2018-2019-La-Liga-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'Ligue 1 2018-2019',
#   'url': 'https://fbref.com/en/comps/13/2018-2019/schedule/2018-2019-Ligue-1-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'Eredivisie 2018-2019',
#   'url': 'https://fbref.com/en/comps/20/2018-2019/schedule/2018-2019-Eredivisie-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'Primeira Liga 2018-2019',
#   'url': 'https://fbref.com/en/comps/19/2018-2019/schedule/2018-2019-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'EFL Championship 2018-2019',
#   'url': 'https://fbref.com/en/comps/10/2018-2019/schedule/2018-2019-EFL-Championship-Scores-and-Fixtures',
#   'season': '2018/2019'},
#  {'name': 'Bundesliga 2017-2018',
#   'url': 'https://fbref.com/en/comps/20/2017-2018/schedule/2017-2018-Bundesliga-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'Premier League 2017-2018',
#   'url': 'https://fbref.com/en/comps/9/2017-2018/schedule/2017-2018-Premier-League-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'Serie A 2017-2018',
#   'url': 'https://fbref.com/en/comps/11/2017-2018/schedule/2017-2018-Serie-A-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'La Liga 2017-2018',
#   'url': 'https://fbref.com/en/comps/12/2017-2018/schedule/2017-2018-La-Liga-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'Ligue 1 2017-2018',
#   'url': 'https://fbref.com/en/comps/13/2017-2018/schedule/2017-2018-Ligue-1-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'Eredivisie 2017-2018',
#   'url': 'https://fbref.com/en/comps/20/2017-2018/schedule/2017-2018-Eredivisie-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'Primeira Liga 2017-2018',
#   'url': 'https://fbref.com/en/comps/19/2017-2018/schedule/2017-2018-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'EFL Championship 2017-2018',
#   'url': 'https://fbref.com/en/comps/10/2017-2018/schedule/2017-2018-EFL-Championship-Scores-and-Fixtures',
#   'season': '2017/2018'},
#  {'name': 'Bundesliga 2016-2017',
#   'url': 'https://fbref.com/en/comps/20/2016-2017/schedule/2016-2017-Bundesliga-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'Premier League 2016-2017',
#   'url': 'https://fbref.com/en/comps/9/2016-2017/schedule/2016-2017-Premier-League-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'Serie A 2016-2017',
#   'url': 'https://fbref.com/en/comps/11/2016-2017/schedule/2016-2017-Serie-A-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'La Liga 2016-2017',
#   'url': 'https://fbref.com/en/comps/12/2016-2017/schedule/2016-2017-La-Liga-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'Ligue 1 2016-2017',
#   'url': 'https://fbref.com/en/comps/13/2016-2017/schedule/2016-2017-Ligue-1-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'Eredivisie 2016-2017',
#   'url': 'https://fbref.com/en/comps/20/2016-2017/schedule/2016-2017-Eredivisie-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'Primeira Liga 2016-2017',
#   'url': 'https://fbref.com/en/comps/19/2016-2017/schedule/2016-2017-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'EFL Championship 2016-2017',
#   'url': 'https://fbref.com/en/comps/10/2016-2017/schedule/2016-2017-EFL-Championship-Scores-and-Fixtures',
#   'season': '2016/2017'},
#  {'name': 'Bundesliga 2015-2016',
#   'url': 'https://fbref.com/en/comps/20/2015-2016/schedule/2015-2016-Bundesliga-Scores-and-Fixtures',
#   'season': '2015/2016'},
#  {'name': 'Premier League 2015-2016',
#   'url': 'https://fbref.com/en/comps/9/2015-2016/schedule/2015-2016-Premier-League-Scores-and-Fixtures',
#   'season': '2015/2016'},
#  {'name': 'Serie A 2015-2016',
#   'url': 'https://fbref.com/en/comps/11/2015-2016/schedule/2015-2016-Serie-A-Scores-and-Fixtures',
#   'season': '2015/2016'},
#  {'name': 'La Liga 2015-2016',
#   'url': 'https://fbref.com/en/comps/12/2015-2016/schedule/2015-2016-La-Liga-Scores-and-Fixtures',
#   'season': '2015/2016'},
#  {'name': 'Ligue 1 2015-2016',
#   'url': 'https://fbref.com/en/comps/13/2015-2016/schedule/2015-2016-Ligue-1-Scores-and-Fixtures',
#   'season': '2015/2016'},
#  {'name': 'Eredivisie 2015-2016',
#   'url': 'https://fbref.com/en/comps/20/2015-2016/schedule/2015-2016-Eredivisie-Scores-and-Fixtures',
#   'season': '2015/2016'},
#  {'name': 'Primeira Liga 2015-2016',
#   'url': 'https://fbref.com/en/comps/19/2015-2016/schedule/2015-2016-Primeira-Liga-Scores-and-Fixtures',
#   'season': '2015/2016'},
#  {'name': 'EFL Championship 2015-2016',
#   'url': 'https://fbref.com/en/comps/10/2015-2016/schedule/2015-2016-EFL-Championship-Scores-and-Fixtures',
#   'season': '2015/2016'}]
